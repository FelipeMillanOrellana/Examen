# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeMillanOrellana/Examen/blob/main/Felipe_Mill%C3%A1nPGY1121_012V.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
nombre = input(str("Ingrese el nombre del cliente: "))
apellido = input(str("Ingrese el apellido del cliente: "))
productos = np.array([], dtype=[('id', 'U100'), ('tipo_producto', 'U100'), ('marca','U100'), ('modelo','U100'), ('precio', int)])

def validar_id(id):
  return len(id)>=5

def validar_tipo_producto(tipo_producto):
  return len(tipo_producto)>=8

def grabar_producto():
    global productos

    while True:
        id = input("Ingrese el Id del producto: ")
        if validar_id(id):
          break
        else:
          print("Id invalido debe tener 3 letras y de 2 a 6 números")

    while True:
        tipo_producto = input("Ingrese el tipo de producto: ")
        if validar_tipo_producto(tipo_producto):
          break
        else:
          print("tipo de producto invalido debe tener almenos 8 caracteres")

    marca = input("Ingrese la marca del producto: " )

    modelo = input("Ingrese el modelo del producto: ")

    while True:
        precio = int(input("Ingrese el precio del producto: "))
        if precio > 0:
            break
        else:
            print("Precio inválido. Debe ser mayor a cero.")

    producto = np.array([(id, tipo_producto, marca, modelo, precio)], dtype=productos.dtype)

    productos = np.concatenate([productos, producto])

    print("Producto grabado exitosamente.")

def buscar_producto():

    global productos

    id = input("Ingrese el Id del producto que desea buscar: ")
    encontrado = False

    for producto in productos:
        if producto["id"] == id:
            encontrado = True
            if producto["precio"] >= 1:
                print("Id:", producto["id"])
                print("Tipo de producto:", producto["tipo_producto"])
                print("Marca del producto", producto["marca"])
                print("Modelo del producto", producto["modelo"])
                print("Precio del Producto:", producto["precio"])
            else:
                print("Producto sin stock")
            break
    if not encontrado:
        print("Producto no encontrado.")

def imprimir_cotizacion():
    global productos

    for producto in productos:
      print("Id:", producto["id"])
      print("Tipo de producto:", producto["tipo_producto"])
      print("Marca del producto", producto["marca"])
      print("Modelo del producto", producto["modelo"])
      print("Precio del Producto:", producto["precio"])
      print()

def salir_programa(nombre, apellido):
    print("¡Gracias por usar el programa!")
    print("Nombre Cliente:", nombre, apellido)
    exit()

def mostrar_menu():
    print("------ Menú ------")
    print("Ingrese una de las sigientes opcciones")
    print("1. Grabar")
    print("2. Buscar")
    print("3. Imprimir")
    print("4. Salir")

while True:
  mostrar_menu()
  opcion = input("Ingrese una opción: ")
  try:
    if opcion == "1":
      grabar_producto()
    elif opcion == "2":
      buscar_producto()
    elif opcion == "3":
      imprimir_cotizacion()
    elif opcion == "4":
      print("Gracias por su tiempo")
      print(nombre,apellido)
      break
  except:
    print("Opción no valida. Por favor ingrese una opción válida.")
# Out:
# Ingrese el nombre del cliente: felipe
# Ingrese el apellido del cliente: millan
# ------ Menú ------
# Ingrese una delas sigientes opcciones
# 1. Grabar
# 2. Buscar
# 3. Imprimir
# 4. Salir
# Ingrese una opción: 1
# Ingrese el Id del producto: def234
# Ingrese el tipo de producto: asasdsdas
# Ingrese la marca del producto: asdwdsad
# Ingrese el modelo del producto: sdwasd
# Ingrese el precio del producto: wdsdawd
# Opción no valida. Por favor ingrese una opción válida.
# ------ Menú ------
# Ingrese una delas sigientes opcciones
# 1. Grabar
# 2. Buscar
# 3. Imprimir
# 4. Salir
# Ingrese una opción: 1
# Ingrese el Id del producto: asd123
# Ingrese el tipo de producto: wdwadwa
# tipo de producto invalido debe tener almenos 8 caracteres
# Ingrese el tipo de producto: wadwadwdawd
# Ingrese la marca del producto: wdsadwsdadw
# Ingrese el modelo del producto: wadwd
# Ingrese el precio del producto: 20000
# Producto grabado exitosamente.
# ------ Menú ------
# ...

# %%
import numpy as np
nombre = input(str("Ingrese el nombre del cliente: "))
apellido = input(str("Ingrese el apellido del cliente: "))
#ingresar lo que pida el ejercicio , la cantidad de caracteres
#por respuesta si es que es una respuesta escrita o colocar int si es una respuesta númerica de enteros
productos = np.array([], dtype=[('id', 'U100'), ('tipo_producto', 'U100'), ('marca','U100'), ('modelo','U100'), ('precio', int)])
#definir las opciones y el retorno de datos/caracteres
def validar_id(id):
  return len(id)>=5

def validar_tipo_producto(tipo_producto):
  return len(tipo_producto)>=8

def grabar_producto():
    global productos

    while True:
        id = input("Ingrese el Id del producto: ")
        if validar_id(id):
          break
        else:
          print("Id invalido debe tener 3 letras y de 2 a 6 números")

    while True:
        tipo_producto = input("Ingrese el tipo de producto: ")
        if validar_tipo_producto(tipo_producto):
          break
        else:
          print("tipo de producto invalido debe tener almenos 8 caracteres")

    marca = input("Ingrese la marca del producto: " )

    modelo = input("Ingrese el modelo del producto: ")

    while True:
        precio = int(input("Ingrese el precio del producto: "))
        if precio > 0:
            break
        else:
            print("Precio inválido. Debe ser mayor a cero.")

    producto = np.array([(id, tipo_producto, marca, modelo, precio)], dtype=productos.dtype)

    productos = np.concatenate([productos, producto])

    print("Producto grabado exitosamente.")

def buscar_producto():

    global productos

    id = input("Ingrese el Id del producto que desea buscar: ")
    encontrado = False

    for producto in productos:
        if producto["id"] == id:
            encontrado = True
            if producto["precio"] >= 1:
                print("Id:", producto["id"])
                print("Tipo de producto:", producto["tipo_producto"])
                print("Marca del producto", producto["marca"])
                print("Modelo del producto", producto["modelo"])
                print("Precio del Producto:", producto["precio"])
            else:
                print("Producto sin stock")
            break
    if not encontrado:
        print("Producto no encontrado.")

def imprimir_cotizacion():
    global productos

    for producto in productos:
      print("Id:", producto["id"])
      print("Tipo de producto:", producto["tipo_producto"])
      print("Marca del producto", producto["marca"])
      print("Modelo del producto", producto["modelo"])
      print("Precio del Producto:", producto["precio"])
      print()

def salir_programa(nombre, apellido):
    print("¡Gracias por usar el programa!")
    print("Nombre Cliente:", nombre, apellido)
    exit()

def mostrar_menu():
    print("------ Menú ------")
    print("Ingrese una delas sigientes opcciones")
    print("1. Grabar")
    print("2. Buscar")
    print("3. Imprimir")
    print("4. Salir")
#recordar usar try y except
while True:
  mostrar_menu()
  opcion = input("Ingrese una opción: ")
  try:
    if opcion == "1":
      grabar_producto()
    elif opcion == "2":
      buscar_producto()
    elif opcion == "3":
      imprimir_cotizacion()
    elif opcion == "4":
      print("Gracias por su tiempo")
      print(nombre,apellido)
      break
  except:
    print("Opción no valida. Por favor ingrese una opción válida.")

# %%
from os import replace
import numpy as np

flag=True
opcion=0
ganancias=0
ganancias_t=0
cant=0
ent=0
def mostrar_menu():
  print("Bienvendos a la pagina oficial de crativos\n")
  print("------ Menú ------")
  print("Ingrese una de las sigientes opcciones")
  print("1. Comprar entradas")
  print("2. Mostrar ubicaciones disponibles")
  print("3. Ver listado de asistentes")
  print("4. Mostrar ganancias totales")
  print("5. Salir")
while True:
  mostrar_menu()
  opcion = input("Ingrese una opción: ")
  try:
    if opcion == 1:
      print("Estos son los tipo de entrada \n1)Platinum = $120.000")
      print("n2)Gold = $80.000 \n3)Silver = 50.000")
      lugar = print(input("¿Qué entrada desea comprar? :"))
      if lugar == 1:
        print("A selecionado las entradas Platinum")
      ent1 = print(input(int("Cuantas entradas desea comprar: ")))
      pla = 120000
      cant = cant*pla
      posicion = print(input("Puede escoger entre los acientos del 1A al 2J"))

      elif lugar == 2:
        print("A selecionado las entradas Gold")
        ent2 = print(input(int("Cuantas entradas desea comprar: ")))
        gold = 80000
        cant = cant*gold
        posicion = print(input("Puede escoger entre los acientos del 1A al 2J"))
      elif lugar ==3:
        print("A seleionado las entradas Silver")
        ent3 = print(input(int("Cuantas entradas desea comprar: ")))
        silv = 50000
        cant = cant*silv
        posicion = print(input("Puede escoger entre los acientos del 1A al 2J"))
      else:
        print("Opcion invalida, Selecione una de la opciones mencionadas")

    def lugares():
        print("     Asientos disponibles")
        print("-"*29)
        filas = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I','J']
        for num in range(0, 10):
          for letra in filas :
            print(str(num) + letra, end=" ")
            print()
    lugares()

    elif opcion == "3":
      print(lugares())

    elif opcion == "4":
      def most_gan_totales()

    elif opcion == "5":
      print("Gracias por su tiempo")
      print(nombre,apellido)
      break
  except:
    print("Opción no valida. Por favor ingrese una opción válida.")
# Out:
#   File "<ipython-input-19-e3106be9ede3>", line 32
#     elif opcion == "3":
#     ^
# SyntaxError: invalid syntax

# %%
# Out:
# Bienvenidos a la pagina ofcila de Creativos
# --------------------
# 1. Comprar entradas
# 2. Mostrar ubicaciones disponibles
# 3. Ver listado de asistentes
# 4. Mostrar ganancias totales
# 5. Salir
# Ingrese una opción: 5
# Ingrese su nombre: felipe
# Ingrese su apellido: millan
# Gracias por utilizar el sistema, felipe millan. ¡Hasta luego!
# Fecha de salida: 2023-07-14T01:46:35

# %%
import numpy as np

entradas_platinum = np.empty(20, object)
entradas_gold = np.empty(30, object)
entradas_silver = np.empty(50, object)
asistentes = []

def menu():
    while True:
        print("Bienvenidos a la pagina ofcila de Creativos")
        print("-"*45)
        print("1. Comprar entradas")
        print("2. Mostrar ubicaciones disponibles")
        print("3. Ver listado de asistentes")
        print("4. Mostrar ganancias totales")
        print("5. Salir")
        opcion = input("Ingrese una opción: ")

        if opcion == "1":
            comprar_entradas()
        elif opcion == "2":
            mostrar_ubicaciones_disponibles()
        elif opcion == "3":
            ver_listado_asistentes()
        elif opcion == "4":
            mostrar_ganancias_totales()
        elif opcion == "5":
            nombre = input(str("Ingrese su nombre: "))
            apellido = input(str("Ingrese su apellido: "))
            fecha_actual = obtener_fecha_actual()
            print(f"Gracias por utilizar el sistema, {nombre} {apellido}. ¡Hasta luego!")
            break
        else:
            print("Opción inválida. Por favor, ingrese una opción válida.")

def comprar_entradas():
    print("Comprar entradas")
    cantidad = input("Ingrese la cantidad de entradas a comprar : ")

    if cantidad.isdigit() and 1 <= int(cantidad) <= 3:
        cantidad = int(cantidad)
        mostrar_ubicaciones()
        seleccionar_ubicaciones(cantidad)
    else:
        print("Cantidad inválida. Debe ingresar un número entre 1 y 3.")

def mostrar_ubicaciones():
    print("Ubicaciones disponibles:")
    print("Platinum:", np.count_nonzero(entradas_platinum == X))
    print("Gold:", np.count_nonzero(entradas_gold == X))
    print("Silver:", np.count_nonzero(entradas_silver == X))

def seleccionar_ubicaciones(cantida):
    for i in range(cantida):
        ubicacion = input(f"Ingrese la ubicación {i + 1}: ")

        if ubicacion.isdigit():
            ubicacion = int(ubicacion)

            if ubicacion >=1 and ubicacion <= 20:
                if entradas_platinum[ubicacion - 1] is None:
                    run = input("Ingrese el RUN (sin puntos ni guiones): ")

                    if run.isdigit():
                        asistentes.append({"run": run, "ubicacion": f"Platinum-{ubicacion}"})
                        entradas_platinum[ubicacion - 1] = run
                        print("Operación realizada correctamente.")
                    else:
                        print("RUN inválido. Debe ingresar un número.")
                else:
                    print("Ubicación no disponible.")
            else:
                print("Ubicación inválida. Debe ingresar un número entre 1 y 20.")
        elif ubicacion.isdigit():
            ubicacion = int(ubicacion)

            if ubicacion>=21 and ubicación <= 50:
                if entradas_gold[ubicacion - 21] is None:
                    run = input("Ingrese el RUN (sin puntos ni guiones): ")

                    if run.isdigit():
                        asistentes.append({"run": run, "ubicacion": f"Gold-{ubicacion}"})
                        entradas_gold[ubicacion - 21] = run
                        print("Operación realizada correctamente.")
                    else:
                        print("RUN inválido. Debe ingresar un número.")
                else:
                    print("Ubicación no disponible.")
            else:
                print("Ubicación inválida. Debe ingresar un número entre 21 y 50.")
        elif ubicacion.isdigit():
            ubicacion = int(ubicacion)

            if ubicacion>= 51 and ubicacion <= 100:
                if entradas_silver[ubicacion - 51] is None:
                    run = input("Ingrese el RUN (sin puntos ni guiones): ")

                    if run.isdigit():
                        asistentes.append({"run": run, "ubicacion": f"Silver-{ubicacion}"})
                        entradas_silver[ubicacion - 51] = run
                        print("Operación realizada correctamente.")
                    else:
                        print("RUN inválido. Debe ingresar un número.")
                else:
                    print("Ubicación no disponible.")
            else:
                print("Ubicación inválida, debe ingresar un número entre 51 y 100.")
        else:
            print("Ubicación inválida, debe ingresar un número.")

def mostrar_ubicaciones_disponibles():
    print("Estado actual de la venta de entradas:")
    print("Platinum:", entradas_platinum)
    print("Gold:", entradas_gold)
    print("Silver:", entradas_silver)

def ver_listado_asistentes():
    print("Listado de asistentes:")
    asistentes_ordenados = sorted(asistentes, key=lambda x: int(x["run"]))
    for asistente in asistentes_ordenados:
        print(f"RUN: {asistente['run']}, Ubicación: {asistente['ubicacion']}")

def mostrar_ganancias_totales():
    print("Total ganado por concepto de entradas:")
    total_platinum = 120000 * np.count_nonzero(entradas_platinum == None)
    total_gold = 80000 * np.count_nonzero(entradas_gold == None)
    total_silver = 50000 * np.count_nonzero(entradas_silver == None)
    total = total_platinum + total_gold + total_silver

    print("Tipo Entrada\tCantidad\tTotal")
    print(f"Platinum\t{np.count_nonzero(entradas_platinum == None)}\t\t${total_platinum}")
    print(f"Gold\t\t{np.count_nonzero(entradas_gold == None)}\t\t${total_gold}")
    print(f"Silver\t\t{np.count_nonzero(entradas_silver == None)}\t\t${total_silver}")
    print(f"TOTAL\t\t{np.count_nonzero(entradas_platinum == None) + np.count_nonzero(entradas_gold == None) + np.count_nonzero(entradas_silver == None)}\t\t${total}")
menu()
# Out:
# Bienvenidos a la pagina ofcila de Creativos
# ---------------------------------------------
# 1. Comprar entradas
# 2. Mostrar ubicaciones disponibles
# 3. Ver listado de asistentes
# 4. Mostrar ganancias totales
# 5. Salir
# Ingrese una opción: 5
# Ingrese su nombre: 3
# Ingrese su apellido: 4
# Gracias por utilizar el sistema, 3 4. ¡Hasta luego!
